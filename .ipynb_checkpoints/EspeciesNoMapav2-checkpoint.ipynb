# %%
import json
nome_arquivo = 'sample-formatted.json'
data= {}
i = 0
with open(nome_arquivo, 'r') as f:
    for line in f:
        new_data = json.loads(line)
        data.update({i: new_data})
        i += 1

# %%
import pandas as pd

df = pd.DataFrame.from_dict(data, orient='index')

df_taxon = pd.json_normalize(df['taxon'])
df = pd.concat([df, df_taxon], axis=1)
df = df.drop('taxon', axis=1)

df_locations = pd.json_normalize(df['locations'])
df = pd.concat([df, df_locations], axis=1)
df = df.drop('locations', axis=1)

df = df[['year_published','red_list_category','scientific_name','sis_id',
         'kingdom_name','phylum_name','class_name','order_name',
         'family_name']]
df = df.drop_duplicates(subset = 'scientific_name', keep = 'last')

#Escolher uma classe: opcional
classe = 'ACTINOPTERYGII'
df = df[df['class_name'] == classe]
df = df.reset_index(drop=True)

# %%
import geopandas as gpd

especiegeo =  gpd.read_file('FW_FISH_PART1.shp', encoding='utf-8')
# pd.concat([gpd.read_file('FW_FISH_PART1.shp'), gpd.read_file('FW_FISH_PART2.shp')], ignore_index=True)
#especiegeo.dropna(subset='geometry', inplace=True)
especiegeo = especiegeo[['sci_name', 'geometry']].merge(df, left_on='sci_name', right_on='scientific_name', how='inner')

mundo = gpd.read_file('world-administrative-boundaries.shp')

# %%
mapeamentoCategorias = {'LC': 'Menor Preocupação',
                        'LR/lc': 'Menor Preocupação',
                        'EN': 'Ameaçado',
                        'E': 'Ameaçado',
                        'NT': 'Pouco Ameaçado',
                        'LR/nt': 'Pouco Ameaçado',
                        'LR/cd': 'Pouco Ameaçado',
                        'VU': 'Vulnerável',
                        'V': 'Vulnerável',
                        'RE': 'Extinto Regionalmente',
                        'DD': 'Sem Dados de Risco',
                        'I': 'Sem Dados de Risco',
                        'K': 'Sem Dados de Risco',
                        'R': 'Sem Dados de Risco',
                        'CR': 'Criticamente Ameaçado',
                        'NA': 'Risco Não Avaliado',
                        'NE': 'Risco Não Avaliado',
                        'EX': 'Extinto',
                        'Ex': 'Extinto',
                        'Ex?': 'Extinto',
                        'EW': 'Extinto na Natureza'}

# %% [markdown]
# Espécies sugeridas: Campylomormyrus curvirostris, Neobola moeruensis, Garra wanae, Nipponocypris sieboldii, Barbodes binotatus, Pseudobarbus erubescens, Pungu maclareni, Melanocharacidium blennioides, Barbodes palata, Characodon garmani

# %%
#matplotlib
especie = 'Campylomormyrus curvirostris'
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import warnings
warnings.filterwarnings('ignore')

if especie not in especiegeo['scientific_name'].unique():
    print("Espécie não encontrada")
    exit()

else:

  catRisco = [especiegeo[especiegeo['scientific_name'] == especie]][0].reset_index().iloc[0]['red_list_category']
  catRiscopt = mapeamentoCategorias[catRisco]

  #retangulo em volta da regiao da especia
  lonmin, latmin, lonmax, latmax = especiegeo[especiegeo['scientific_name'] == especie].total_bounds
  lonmin, latmin, lonmax, latmax = lonmin - 5, latmin - 5, lonmax + 5, latmax + 5

  fig, axes = plt.subplots(2, 1, figsize = (10,10))

  #primero mapa
  axes[0].set_aspect('equal')
  mundo.plot(ax=axes[0], color='peachpuff', edgecolor='tan', linewidth=0.3)
  especiegeo[especiegeo['scientific_name'] == especie].plot(ax=axes[0], color='darkred')
  axes[0].set_title('Distribuição da espécie ' + especie + ' em Categoria de Risco ' + catRisco + ': ' + catRiscopt)
  axes[0].add_patch(Rectangle((lonmin, latmin), lonmax-lonmin, latmax-latmin,
                              edgecolor='darkred',
                              facecolor='none',
                              lw=1))

  #segundo mapa
  axes[1].set_aspect('equal')
  mundo.plot(ax=axes[1], color='peachpuff', edgecolor='tan', linewidth=0.5)
  especiegeo[especiegeo['scientific_name'] == especie].plot(ax=axes[1], color='darkred')
  for x, y, label in zip(mundo.geometry.centroid.x, mundo.geometry.centroid.y, mundo.name):
      if x >= lonmin and x <= lonmax and y >= latmin and y <= latmax:
        axes[1].text(x, y, label, fontsize=8, ha='center', va='center')
  axes[1].axis([lonmin, lonmax, latmin, latmax])


  plt.show()

# %%
#plotly
especie = 'Campylomormyrus curvirostris'
import plotly.express as px

gdf = especiegeo[especiegeo['scientific_name'] == especie]
gdf['id'] = gdf.index

fig = px.choropleth(
    gdf,
    geojson=gdf.__geo_interface__,
    locations='id',
    color_discrete_map= {especie:'#871108'},
    color='scientific_name',
)
fig.update_layout(
    title_text='Distribuição da espécie ' + especie,
    showlegend = False,
    geo=dict(
        showframe=False,
        showcoastlines=False,
        showcountries=True,
        projection_type='equirectangular',
        fitbounds="geojson",
    ),
    annotations = [dict(
        x=0.55,
        y=0.1,
        xref='paper',
        yref='paper',
        showarrow = False
    )]
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="638c48f7-8e4d-4b63-a2dc-93b967cd319f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("638c48f7-8e4d-4b63-a2dc-93b967cd319f")) {                    Plotly.newPlot(                        "638c48f7-8e4d-4b63-a2dc-93b967cd319f",                        [{"colorscale":[[0.0,"#871108"],[1.0,"#871108"]],"geo":"geo","geojson":{"type":"FeatureCollection","features":[{"id":"0","type":"Feature","properties":{"sci_name":"Campylomormyrus curvirostris","year_published":"2010","red_list_category":"LC","scientific_name":"Campylomormyrus curvirostris","sis_id":181681,"kingdom_name":"ANIMALIA","phylum_name":"CHORDATA","class_name":"ACTINOPTERYGII","order_name":"OSTEOGLOSSIFORMES","family_name":"MORMYRIDAE","id":0},"geometry":{"type":"MultiPolygon","coordinates":[[[[16.570833333000053,-0.8499999999999659],[16.573043823000035,-0.8494327119999525],[16.58241356800005,-0.8410837809999521],[16.58423292300006,-0.8339945479999642],[16.599100409000073,-0.8326721189999375],[16.600567288000036,-0.8269561769999427],[16.60359937800007,-0.8230438239999671],[16.60473395400004,-0.8075866699999779],[16.600567288000036,-0.8022104899999363],[16.599432712000066,-0.7990119089999439],[16.611932712000055,-0.7855438239999444],[16.612500000000068,-0.7708333329999277],[16.613274638000064,-0.7632392029999551],[16.63130171100005,-0.7618572659999359],[16.63623843700003,-0.758356899999967],[16.637500000000045,-0.7541666659999464],[16.637500000000045,-0.7499999999999432],[16.636882358000037,-0.7478398639999568],[16.63395097500006,-0.7438268029999335],[16.632715691000044,-0.741197543999931],[16.636938477000058,-0.7354166669999245],[16.633219401000076,-0.7303254869999591],[16.625768196000024,-0.7281950209999764],[16.624382358000048,-0.7186731979999763],[16.621450975000073,-0.7146601359999636],[16.620215691000055,-0.7103398639999341],[16.616335551000077,-0.7050281099999438],[16.60490180100004,-0.7033640549999518],[16.604166666000026,-0.6958333329999391],[16.593408882000062,-0.6961866589999772],[16.589924452000048,-0.6996466749999399],[16.57257554800003,-0.7003533259999699],[16.569091119000063,-0.7038133409999432],[16.56666666600006,-0.704166665999935],[16.546749030000058,-0.7035681829999589],[16.544920010000055,-0.6964408029999731],[16.529166666000037,-0.6958333329999391],[16.52576819500007,-0.6948616879999463],[16.524192979000077,-0.6840389679999248],[16.506173198000056,-0.6827156919999311],[16.502160136000043,-0.6797843079999666],[16.493673198000067,-0.6785490249999384],[16.485493469000062,-0.6714509749999706],[16.480093045000046,-0.6699069549999308],[16.478549025000063,-0.6645065309999723],[16.474200100000076,-0.659068806999926],[16.460339864000048,-0.6577156919999538],[16.452160136000032,-0.6506176419999292],[16.443673197000066,-0.6493823579999685],[16.439660136000043,-0.6464509749999365],[16.437500000000057,-0.6458333329999277],[16.435075548000043,-0.6454800079999359],[16.40833401200007,-0.6187639029999445],[16.41248575900005,-0.6145829939999317],[16.40662350100007,-0.6086914069999807],[16.40174221500007,-0.60798000799997],[16.398257785000055,-0.6045199919999504],[16.39583333400003,-0.6041666669999586],[16.389506531000052,-0.6035490249999498],[16.384492153000053,-0.5998860679999325],[16.38212076800005,-0.5915920679999545],[16.377160136000043,-0.5952156919999538],[16.368673197000078,-0.5964509749999252],[16.364660136000055,-0.5993823579999571],[16.353697544000056,-0.6006176419999747],[16.347993469000073,-0.5964509749999252],[16.342593045000058,-0.5949069549999422],[16.341049025000075,-0.5895065309999268],[16.338117642000043,-0.5854934689999709],[16.336551412000063,-0.5747326319999502],[16.331326802000035,-0.5785490249999725],[16.328697544000022,-0.5797843079999438], ...
